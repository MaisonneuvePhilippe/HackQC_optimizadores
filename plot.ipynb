# %%
import matplotlib.pyplot as plt
import random
import numpy as np
prod = [15660.0, 15536.0, 15401.0, 15397.0, 15264.0, 15298.0, 15356.0, 15223.0, 15216.0, 15210.0, 15286.0, 15215.0, 15184.0, 15184.0, 15157.0, 15316.0, 15407.0, 15338.0, 15412.0, 15588.0, 15818.0, 15857.0, 15935.0, 16276.0, 16554.0, 16745.0, 16679.0, 16996.0, 17164.0, 17414.0, 17492.0, 17513.0, 17718.0, 17880.0, 18066.0, 17954.0, 18126.0, 18025.0, 18146.0, 18108.0, 18134.0, 18131.0, 18071.0, 18074.0, 18106.0, 18087.0, 17912.0, 17861.0, 17840.0, 17741.0, 17627.0, 17414.0, 17297.0, 17284.0, 17118.0, 17129.0, 17020.0, 16998.0, 16850.0, 17009.0, 17009.0, 17177.0, 17151.0, 17391.0]
prod = [i *1.5 for i in prod]
pred = [26256.0, 26352.5, 26804.5, 27104.0, 26927.5, 26976.0, 27396.5, 27547.0, 27502.0, 27341.5, 27398.5, 27388.0, 27177.0, 27542.0, 27404.5, 27517.0, 27328.0, 27415.0, 27128.0, 26507.0, 26414.5, 26558.0, 26097.0, 25776.0, 25872.0, 24950.5, 25513.5, 24929.0, 24718.0, 23813.5, 24175.5, 24125.0, 23702.0]
plt.xticks(np.arange(0, len(prod)+len(pred) + 1, 4), labels=[str(i) for i in range(25)])
plt.plot(range(0,64), prod)
plt.plot(range(64,97), pred,  linestyle='dashed',)


print(prod + pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [88], line 6
#       4 prod = [i *1.5 for i in prod]
#       5 pred = [26256.0, 26352.5, 26804.5, 27104.0, 26927.5, 26976.0, 27396.5, 27547.0, 27502.0, 27341.5, 27398.5, 27388.0, 27177.0, 27542.0, 27404.5, 27517.0, 27328.0, 27415.0, 27128.0, 26507.0, 26414.5, 26558.0, 26097.0, 25776.0, 25872.0, 24950.5, 25513.5, 24929.0, 24718.0, 23813.5, 24175.5, 24125.0, 23702.0]
# ----> 6 plt.xticks(np.arange(0, len(prod)+len(pred) + 1, 4), labels=[str(i) for i in range(25)])
#       7 plt.plot(range(0,64), prod)
#       8 plt.plot(range(64,97), pred,  linestyle='dashed',)
#
# NameError: name 'np' is not defined

# %%
def production_to_price(production):
    price = []

    for i in range(len(production)):
        price.append(
            2*(2.6983 * 10**-12 * production[i] ** 3
            - 7.6478 * 10**-8 * production[i] ** 2
            + 3.5189 * 10**-4 * production[i]
            + 6),
        )
    return price

# %%
price = production_to_price(prod)
price_pred = production_to_price(pred)

plt.xticks(np.arange(0, len(soc) + 1, 4), labels=[str(i) for i in range(25)])
plt.plot(range(0,64), price)
plt.plot(range(64,97), price_pred,  linestyle='dashed',)
